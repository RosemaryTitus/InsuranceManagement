-- %% [markdown]
-- # [dbo].[Users]

-- %%
USE [InsuranceManagementDatabase]
GO

-- %%
INSERT [dbo].[Users] ([Id], [Name], [Email], [Password], [Role]) VALUES (1, N'anu', N'anurose', N'$2a$11$Iso1xqSnjW56vvAGfbWXvOnnkMEyow4ssX3j2lvqQVZsZKAfXOGQG', N'Customer')
INSERT [dbo].[Users] ([Id], [Name], [Email], [Password], [Role]) VALUES (2, N'angel', N'angel24', N'$2a$11$WdLbCEOrYZRJxWf1Q.amwu3NHEBmwAaNtIRpch5XaR/pFiwVHl7.m', N'Admin')
INSERT [dbo].[Users] ([Id], [Name], [Email], [Password], [Role]) VALUES (3, N'rose', N'rose25', N'$2a$11$YlfOnbr5vMJAQmXjsnASYe8SmFThBM2ZZ8YS7WNW/hrLkW3aXJRY6', N'Admin')
INSERT [dbo].[Users] ([Id], [Name], [Email], [Password], [Role]) VALUES (4, N'ben', N'ben23', N'$2a$11$6ySF0AbXXnfzkQLvhwA6BOGDew0udCu5TtW3qoJef3qCa.6m4DP/O', N'Customer')
GO

-- %% [markdown]
-- # [dbo].[Policy_Type]

-- %%
INSERT [dbo].[Policy_Type] ([Id], [RGID], [TypeName], [Description], [EffectiveFrom], [EffectiveTo], [Status], [LastUpdatedBy], [LastUpdatedOn]) VALUES (1, N'3fa85f64-5717-4562-b3fc-2c963f66afa6', N'Comprehensive Health Insurance Plan', N'Provides extensive health coverage, including inpatient and outpatient treatments', CAST(N'2024-11-28T17:48:31.890' AS DateTime), CAST(N'2024-11-28T23:19:14.790' AS DateTime), 0, N'angel', CAST(N'2024-11-28T23:19:14.790' AS DateTime))
INSERT [dbo].[Policy_Type] ([Id], [RGID], [TypeName], [Description], [EffectiveFrom], [EffectiveTo], [Status], [LastUpdatedBy], [LastUpdatedOn]) VALUES (2, N'3fa85f64-5717-4562-b3fc-2c963f66afa6', N'Comprehensive Vehicle Insurance Policy', N'Provides coverage for damages to your vehicle, theft, third-party liabilities, and personal accident protection', CAST(N'2024-11-28T13:14:28.367' AS DateTime), CAST(N'2025-11-28T13:14:28.367' AS DateTime), 1, N'angel', CAST(N'2024-11-28T18:56:45.507' AS DateTime))
INSERT [dbo].[Policy_Type] ([Id], [RGID], [TypeName], [Description], [EffectiveFrom], [EffectiveTo], [Status], [LastUpdatedBy], [LastUpdatedOn]) VALUES (3, N'3fa85f64-5717-4562-b3fc-2c963f66afa6', N'Education policies', N'Policies governing educational standards, access, and quality.', CAST(N'2024-11-29T06:55:24.457' AS DateTime), CAST(N'2025-11-29T06:55:24.457' AS DateTime), 1, N'rose', CAST(N'2024-11-29T12:30:27.780' AS DateTime))
GO

-- %% [markdown]
-- # [dbo].[Policy]

-- %%
INSERT [dbo].[Policy] ([Id], [RGID], [PolicyNumber], [PolicyTypeId], [EffectiveFrom], [EffectiveTo], [Status], [PremiumAmount], [PaymentFrequency], [PolicyTerm], [LastUpdatedBy], [LastUpdatedOn], [PolicyType]) VALUES (1, N'3fa85f64-5717-4562-b3fc-2c963f66afa6', N'PH0102', 2, CAST(N'2024-11-28T13:14:28.367' AS DateTime), CAST(N'2025-11-28T13:14:28.367' AS DateTime), 1, CAST(90000.00 AS Decimal(30, 2)), 1, N'Car', N'rose', CAST(N'2024-11-30T18:36:46.320' AS DateTime), N'Comprehensive Vehicle Insurance Policy')
GO

-- %% [markdown]
-- # [dbo].[Purchase]

-- %%
INSERT [dbo].[Purchase] ([Id], [RGID], [CustomerId], [PolicyId], [PolicyType], [PurchaseDate], [StartDate], [EndDate], [TotalPremiumAmount], [Status], [PaymentId], [RuleId]) VALUES (1, N'3fa85f64-5717-4562-b3fc-2c963f66afa6', 1, 1, N'Comprehensive Vehicle Insurance Policy', CAST(N'2024-12-04T16:27:13.223' AS DateTime), CAST(N'2024-12-04T16:27:13.223' AS DateTime), CAST(N'2024-12-04T16:27:13.223' AS DateTime), CAST(99000.00 AS Decimal(30, 2)), 1, 1, 1)
GO

-- %% [markdown]
-- # [dbo].[Rules]

-- %%
INSERT [dbo].[Rules] ([Id], [RGID], [PolicyType], [ConditionType], [ConditionOperator], [ConditionValue], [ActionType], [ActionValue], [Description]) VALUES (1, N'3fa85f64-5717-4562-b3fc-2c963f66afa6', N'Car', N'Age', N'>', N'60', N'Add', CAST(10.00 AS Decimal(10, 2)), N'Add 10% to base premium if age is greater than 60')
GO
